# %%
import pandas as pd

# %%
numbers = [10, 20, 30, 40, 50]
series = pd.Series(numbers)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
marks = pd.Series([75, 82, 90, 68], index=["Ali", "Ahmed", "Sara", "Jasim"])

print(marks)
# Out:
# Ali      75
# Ahmed    82
# Sara     90
# Jasim    68
# dtype: int64

# %%
marks = pd.Series([75, 82, 90, 68], index=["Ali", "Ahmed", "Sara", "Jasim"])
print(marks)
# Out:
# Ali      75
# Ahmed    82
# Sara     90
# Jasim    68
# dtype: int64

# %%
print("First Value:", marks["Ali"])
print("Second Value:", marks["Ahmed"])
# Out:
# First Value: 75
# Second Value: 82
