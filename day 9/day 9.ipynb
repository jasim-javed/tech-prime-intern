# %%
#statistical operations

# %%
import numpy as np

# %%
a=np.array([1,2,3,4])
a
# Out:
# array([1, 2, 3, 4])

# %%
a.mean()
# Out:
# np.float64(2.5)

# %%
a.var()
# Out:
# np.float64(1.25)

# %%
a.std()
# Out:
# np.float64(1.118033988749895)
