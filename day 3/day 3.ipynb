# %%
# boolean variables and evaluation

# %%
10==10
# Out:
# True

# %%
1>.5
# Out:
# True

# %%
2<.3
# Out:
# False

# %%
type(10==10)
# Out:
# bool

# %%
a= 'sample line for testing bool'

# %%
'line' in a
# Out:
# True

# %%
#list

# %%
a= [5,10,'jasim',True]

# %%
type(a)
# Out:
# list

# %%
a.append(5)

# %%
a
# Out:
# [5, 10, 'jasim', True, 5]

# %%
a=a+['her']

# %%
a.extend([56,55])
a
# Out:
# [5, 10, 'jasim', True, 5, 'her', 56, 55]

# %%
a.remove('her')

# %%
a
# Out:
# [5, 10, 'jasim', True, 5, 56, 55]

# %%
a.pop(1)
a
# Out:
# [5, 'jasim', True, 5, 56, 55]

# %%
a.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 a.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
a.pop(1)
a
# Out:
# [5, True, 5, 56, 55]

# %%
a.sort()

# %%
a
# Out:
# [True, 5, 5, 55, 56]

# %%
a.sort(reverse=True)

# %%
a
# Out:
# [56, 55, 5, 5, True]

# %%
#tuple

# %%
b= (5,'jasim')
b, type(b)
# Out:
# ((5, 'jasim'), tuple)

# %%
a=list(b)
a.append(6)
a.append(7)
a
# Out:
# [5, 'jasim', 6, 7]

# %%
b=tuple(a)

# %%
b
# Out:
# (5, 'jasim', 6, 7)

# %%
c=(69,67)

# %%
b+c
# Out:
# (5, 'jasim', 6, 7, 69, 67)

# %%
#set

# %%
a={'jasim',54 }
type (a)
# Out:
# set

# %%
a.remove('jasim')
a
# Out:
# {54}

# %%
a.add('jasim')
a
# Out:
# {54, 'jasim'}

# %%
b={1,2,3}

# %%
a.update(b)

# %%
a
# Out:
# {1, 2, 3, 54, 'jasim'}

# %%
a-b
# Out:
# {54, 'jasim'}

# %%
#dictionary

# %%
a={'one':1,'two':2,'three':3}
a,type(a)
# Out:
# ({'one': 1, 'two': 2, 'three': 3}, dict)

# %%
a['one']
# Out:
# 1

# %%
a['one']=1.0
a
# Out:
# {'one': 1.0, 'two': 2, 'three': 3}

# %%
a.keys()
# Out:
# dict_keys(['one', 'two', 'three'])

# %%
a.values()
# Out:
# dict_values([1.0, 2, 3])

# %%
a.pop('one')
# Out:
# 1.0

# %%
a
# Out:
# {'two': 2, 'three': 3}

# %%
a.popitem()
# Out:
# ('three', 3)

# %%
a
# Out:
# {'two': 2}

# %%
b={'key':'value'}
b
# Out:
# {'key': 'value'}

# %%
a=b.copy()

# %%
a
# Out:
# {'key': 'value'}

# %%
b=a.copy()

# %%
b
# Out:
# {'key': 'value'}

# %%
a
# Out:
# {'key': 'value'}

# %%
b
# Out:
# {'key': 'value'}

# %%
a.update({'b':b})
a
# Out:
# {'key': 'value', 'b': {'key': 'value'}}
