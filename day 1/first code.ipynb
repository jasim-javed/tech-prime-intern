# %%
#

# %%
5+5
# Out:
# 10

# %%
5//3
# Out:
# 1

# %%
5**9
# Out:
# 1953125

# %%
type (5)
# Out:
# int

# %%
type (5.5)
# Out:
# float

# %%
type ('j')
# Out:
# str

# %%
type(False)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %%
type(b"hello")
# Out:
# bytes

# %%
string_text='jasim'

# %%
type(string_text)
# Out:
# str
