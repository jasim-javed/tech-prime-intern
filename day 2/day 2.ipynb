# %%
# variable casting

# %%
a = 5
a , type(a)
# Out:
# (5, int)

# %%
b = float (a)
b , type (b)
# Out:
# (5.0, float)

# %%
int (b)
# Out:
# 5

# %%
str (a)
a , type (a)
# Out:
# (5, int)

# %%
str (a)
# Out:
# '5'

# %%
float (a)
a=float(a)

# %%
d= str (a)
d, type (d)
# Out:
# ('5.0', str)

# %%
int(float(d))
d,type(d)
# Out:
# ('5.0', str)

# %%
print(int(float(d)))
d,type(d)
# Out:
# 5
# ('5.0', str)

# %%
# string operations

# %%
'hello'
# Out:
# 'hello'

# %%
a='jasim here'

# %%
print (a)
# Out:
# jasim here

# %%
a='''use three quotes 
for printing multiple lines'''
print (a)
# Out:
# use three quotes
# for printing multiple lines

# %%
a='''  if there's a qoute in line than use three quotes as well'''
print (a)
# Out:
#   if there's a qoute in line than use three quotes as well

# %%
a='accessing the strings by there index values'

# %%
a
# Out:
# 'accessing the strings by there index values'

# %%
a[5]
# Out:
# 's'

# %%
 a[-1]   #for accessing the last string
# Out:
# 's'

# %%
len(a) #for lenght
# Out:
# 43

# %%
a='jasim'   #combining two strings
b='her'  
a+ '  immpossible to get  ' +b
# Out:
# 'jasim  immpossible to get  her'

# %%
#slicing of a string

# %%
a='accessing the strings by there index values'
a
# Out:
# 'accessing the strings by there index values'

# %%
a[12:35]
# Out:
# 'e strings by there inde'

# %%
a[:30]
# Out:
# 'accessing the strings by there'

# %%
a[-25:]
# Out:
# 'ngs by there index values'

# %%
#string modification

# %%
a='jasim'
b=a.upper()
b
# Out:
# 'JASIM'

# %%
b.lower()
# Out:
# 'jasim'

# %%
b.title()
# Out:
# 'Jasim'

# %%
a='jasim     '
a
# Out:
# 'jasim     '

# %%
a.strip()
# Out:
# 'jasim'

# %%
a.replace('a','A')
# Out:
# 'jAsim     '

# %%
age=19
text='my age is '
text+str(age)
# Out:
# 'my age is 19'

# %%
text='my age is {}'. format(age)
text
# Out:
# 'my age is 19'
