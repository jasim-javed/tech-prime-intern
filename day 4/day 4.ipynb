# %%
#conditional statements

# %%
a=100
b=101
if a>b:
    print('a is larger')
else:
    print('a is smaller')
# Out:
# a is smaller

# %%
a=100
b=101
if a<b:
    c=a+b
    print('a is larger, value of c is {}'.format(c))
else:
    print('a is smaller')
# Out:
# a is larger, value of c is 201

# %%
a=10
b=20

if a>b:
    print('a is greater than b')
elif a<b:
    print ('a is smaller than b')
else:
    print('waro!')
# Out:
# a is smaller than b

# %%
#while loop

# %%
a=10
while (a>=5):
    print (a)
    a=a-1
# Out:
# 10
# 9
# 8
# 7
# 6
# 5

# %%
a=10
while (a>0):
    a=a-1
    if a%2==0:
       continue
    print(a)
# Out:
# 9
# 7
# 5
# 3
# 1

# %%
#for loop

# %%
a=['jasim','her']
for x in a:
 print(x)
# Out:
# jasim
# her

# %%
a=['jasim','her']
for x in a:
    if x=='jasim':
        continue

print (x)
# Out:
# her

# %%
a=['jasim','her','something']
for x in a:
    if x=='her':
       break
print (x)
# Out:
# her

# %%
a
# Out:
# ['jasim', 'her', 'something']

# %%
for x in range(len(a)):
    print (x,a[x])
# Out:
# 0 jasim
# 1 her
# 2 something

# %%
#function

# %%
def addition(a,b):
    c=a+b
    print (c)

# %%
addition(5,9)
# Out:
# 14

# %%
def add(*parameters):
    print('sum of entered numbers is  {}'. format(sum(parameters)))

# %%
add(9,5,7,5)
# Out:
# sum of entered numbers is  26

# %%
def sum(**parameters):
    c=0
    for x in parameters:
       c=c+parameters[x]
    print ('sum is ',c)

c=sum(a=1,b=2,c=3)
# Out:
# sum is  6
