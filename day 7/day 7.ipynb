# %%
#array index and slicing

# %%
import numpy as np

# %%
a=np.array([1,2,3,4])
a[1]
# Out:
# np.int64(2)

# %%
a[-1]
# Out:
# np.int64(4)

# %%
a= np.array([[1,2,3,4],[5,6,7,8]])
a
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
a[0,0]
# Out:
# np.int64(1)

# %%
a[1,2]
# Out:
# np.int64(7)
