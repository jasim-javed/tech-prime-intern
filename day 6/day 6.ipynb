# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.5'

# %%
a= np.array([1,2,3,4])
a,a.shape ,type (a)
# Out:
# (array([1, 2, 3, 4]), (4,), numpy.ndarray)

# %%
a= np.array(1)
a,a.shape
# Out:
# (array(1), ())

# %%
#2d
a= np.array([[1,2,3,4],[5,6,7,8]])
a,a.shape ,type (a)
# Out:
# (array([[1, 2, 3, 4],
#         [5, 6, 7, 8]]),
#  (2, 4),
#  numpy.ndarray)
