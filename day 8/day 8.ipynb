# %%
#numpy data types

# %%
import numpy as np

# %%
a= np.array([1,2,3,4.0])
a,a.dtype
# Out:
# (array([1., 2., 3., 4.]), dtype('float64'))

# %%
a= np.array(['jasim','her'])
a,a.dtype
# Out:
# (array(['jasim', 'her'], dtype='<U5'), dtype('<U5'))

# %%
#np.nan and np.inf

# %%
a=np.nan
b=np.nan
a,b
# Out:
# (nan, nan)

# %%
a==b
# Out:
# False

# %%
a=np.inf
b=np.inf
a,b
# Out:
# (inf, inf)

# %%
a==b
# Out:
# True
