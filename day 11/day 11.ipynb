# %%
# data analysis with panda

# %%
import pandas as pd

# %%
flavors = ['mango', 'chocolate']
pd.Series(flavors)
# Out:
# 0        mango
# 1    chocolate
# dtype: object

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
a = {'a':1,'b':2}

# %%
pd.Series(a)
# Out:
# a    1
# b    2
# dtype: int64

# %%
s=pd.Series(a,index=['a','b','c'])
s.min(),s.max()
# Out:
# (1.0, 2.0)

# %%
# read from file

# %%
s=pd.read_csv()
